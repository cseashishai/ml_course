# %%
grade = [89,69,76,78,99]
grade.append(86)

avrage =sum(grade) / len(grade)

print(f"avrage :{avrage:.2f}")#here is 2f are including to the after . of 2 values are including

heigh =max(grade)
heigh1 =min(grade)
print (heigh)
print(heigh1)
# Out:
# avrage :82.83
# 99
# 69

# %% [markdown]
# Use to mange invotery items in store

# %%
# FIrst to creat invotery
store =["apple","banana","papaya","mango","grips"]

# adding new data
store.append("blackbarry")

# remove data
store.remove("banana")

item = "apple"

#  cheking the item the item will be their in store 

if item in store:
    print(f"{item} are stock:")
else:
    print(f"{item} are not stock")    

# printin the all data
print("in the store of data")
for item in store:
    print(f" - {item}")
# Out:
# apple are stock:
# in the store of data
#  - apple
#  - papaya
#  - mango
#  - grips
#  - blackbarry

# %% [markdown]
# Use to list to feedback to everyone

# %%
# just i first to creat a feedback list
feedback = ["Grate servie","very stisfying!","I recconment to you this type to do","is this batter"]

feedback.append("Not is best to doing")

# counting the all feedback 

positive =sum(1 for comment in feedback if "yes" in comment.lower() or "no" in comment.lower() )
print(f"possitive_feedback : {positive}")

# print all feedbacl

# print("All feedbak")

# for comment in feedback:
#     print(f"- {comment} ")
# Out:
# possitive_feedback : 1
