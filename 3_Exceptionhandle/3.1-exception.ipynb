# %% [markdown]
# Exception handling

# %%
# Exception handling
try:
    a=b
except:
    print("variable not be assigne")
# Out:
# variable not be assigne

# %%
try:
    a=b
except NameError as ex:
    print(ex)
# Out:
# name 'b' is not defined

# %%
try:
    reault= 1/2
    a=b
except ZeroDivisionError as ex:
    print(ex)
    print("enter the daominator")
except Exception as ex1:
    print(ex1)
    print('that will provides got cough')
# Out:
# name 'b' is not defined
# that will provides got cough

# %%
try:
    num=int(input("enter the number"))

    result=10/num
except ValueError  :
    print("This is not  a valid number")

except ZeroDivisionError:
    print("Enter daominatior value grater than 0")    

except Exception as ex:
    print(ex)
# Out:
# Enter daominatior value grater than 0

# %%
## try,except ,else and finally
try:
    num=int(input("enter the number"))

    result=10/num
except ValueError  :
    print("This is not  a valid number")

except ZeroDivisionError:
    print("Enter daominatior value grater than 0")    

else:
    print (f'result is :{result}')    

finally:
    print('Executing complete .')
# Out:
# result is :2.5
# Executing complete .

# %%
# file Handlaing and exception handling

try:
    file =open('example.txt','r')
    content =file.read()
    a=b
    print(content)

except FileNotFoundError:
    print("The file does not exits")

except Exception as ex:
    print(ex)      

finally:
    if file in locals() and file.closed():
        file.close()   
        print('file close')
# Out:
# name 'b' is not defined
