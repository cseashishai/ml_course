# %% [markdown]
# ### Custom exception handling (rise and throw)

# %%
class Error(Exception):
    pass

class deobException(Error):
    pass

# %%
year =int(input("Enter the Dob"))
age =2024-year
try:
    if age <=30 and age>=20:
        print("Age will be valid so you can apply for exam")
    else:
        raise deobException 
except deobException:
    print("soory ,your age will be 20 that less than 30")
# Out:
# soory ,your age will be 20 that less than 30
