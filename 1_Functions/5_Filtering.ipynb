# %% [markdown]
# The Filter() Function in python

# %%
def even(num):
    if num%2==0:
        return True

# %%
# even(24)

# %%
lst =[2,5,4,6,7,8,3,6,9,10]

list(filter(even,lst))
# Out:
# [2, 4, 6, 8, 6, 10]

# %%
# filter by lamda function

number =[1,2,3,4,5,6,7,8]
grater_tahn_five =list(filter(lambda x:x>5,number))
print(grater_tahn_five )
# Out:
# [6, 7, 8]

# %%
# filter the multiple condition using lambda function
number1=[1,2,3,4,5,6,7,8]

the_function =list(filter(lambda x:x>5 and x%2==0,number))
print(the_function)
# Out:
# [6, 8]

# %%
# apply the filtter by cheking grater 25 in dictonary dat

people =[
    {'name':'ashu','age':19},
    {'name':'aman','age':20},
    {'name':'boy','age':30}
    
    ]
def age_grater_then(person):
    return person['age']>25

list(filter(age_grater_then,people))
# Out:
# [{'name': 'boy', 'age': 30}]

# %%
from pakage.math import addition
addition(2,3)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 from pakage.math import addition
#       2 addition(2,3)
#
# ModuleNotFoundError: No module named 'pakage'
